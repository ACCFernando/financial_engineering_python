# %%
import yfinance as yf
import pandas as pd
import seaborn as sns
import yaml

# %%
with open('tickers.yml', 'r') as yml_file:
    tickers = yaml.safe_load(yml_file)
tickers[ticker_list]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 with open('tickers.yml', 'r') as yml_file:
#       2     tickers = yaml.safe_load(yml_file)
# ----> 3 tickers[ticker_list]
#
# NameError: name 'ticker_list' is not defined

# %%
petr = yf.download(
    tickers="PETR4.SA",
    start="2022-01-01",
    end="2022-12-31"
                  )
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
petr.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2022-01-03  28.540001  29.219999  28.530001  29.090000  15.137723  52704700
# 2022-01-04  29.160000  29.400000  28.910000  29.200001  15.194964  51739200
# 2022-01-05  29.190001  29.270000  27.940001  28.070000  14.606940  78459800
# 2022-01-06  28.290001  28.650000  27.840000  28.049999  14.596533  61163100
# 2022-01-07  28.110001  28.290001  27.820000  28.180000  14.664181  47507600

# %%
petr[['Open','Close']].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
ibov = pd.read_csv('data/raw/20230502_ibov.csv',sep=',')

# %%
ibov.head()
# Out:
#   ticker          acao        tipo  qtde_teorica  pc_participacao
# 0  RRRP3  3R PETROLEUM  ON  ES  NM     234689601            0.404
# 1  ALSO3  ALIANSCSONAE  ON  ED  NM     532365440            0.525
# 2  ALPA4    ALPARGATAS  PN      N1     202765994            0.082
# 3  ABEV3     AMBEV S/A          ON    4386652506            3.380
# 4  ARZZ3     AREZZO CO  ON      NM      60758326            0.220
